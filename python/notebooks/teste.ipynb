# %%
# Teste de Jupyter
import sys
print(f"🐍 Python: {sys.version.split()[0]}")
print(f"📍 Executável: {sys.executable}")

# %%
import pandas as pd

# Criar um pequeno DataFrame de exemplo (parecido com o que faremos com dados reais)
dados = {
    "indicador": ["Selic", "IPCA", "Câmbio"],
    "valor":     [10.75,   4.20,    5.42],
}
df = pd.DataFrame(dados)
df

# %%
import requests

resposta = requests.get("https://api.bcb.gov.br/dados/serie/bcdata.sgs.432/dados/ultimos/1?formato=json")
print("Status:", resposta.status_code)
print("Conteúdo:", resposta.json())

# %% [markdown]
# ## Teste concluído ✅
#
# Este notebook confirma que:
# - Python 3.11 funciona no ambiente `painel-economico-brasil`
# - `pandas` e `requests` estão instalados
# - A API do BCB responde e retorna JSON
